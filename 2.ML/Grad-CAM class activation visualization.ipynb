# %% [markdown]
# ## Grad-CAM class activation visualization

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import cv2
# Display
from IPython.display import Image
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
model_builder = keras.applications.inception_resnet_v2.InceptionResNetV2

preprocess_input = keras.applications.inception_resnet_v2.preprocess_input
decode_predictions = keras.applications.inception_resnet_v2.decode_predictions

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Input

# %%
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from keras.applications.inception_resnet_v2 import preprocess_input

image_size = 299
batch_size = 1
valid_size = 1
# 학습 및 검증 데이터용 ImageDataGenerator 생성해 놓기 
train_datagen = ImageDataGenerator(rescale=1./255., 
                                   validation_split = 0.20)

#검증데이터는 정규화 외에 따로 조정 없음 
valid_datagen = ImageDataGenerator(rescale=1./255., 
                                   validation_split = 0.20)

#flow_from_directory()는 앞서 배운 flow()와 비슷, 단 경로를 통채로 가져올 수 있음 
# seed 값이 같으므로 train subset과 validation subset이 중복될 일은 없다.
# batch_size = 32, shuffle=True이므로 랜덤하게 32개의 이미지를 디렉토리에서 골라서 보강하여 반환한다.
train_generator = train_datagen.flow_from_directory(directory = '/content/drive/My Drive/인공지능 학습관련/covid데이터', #저장 경로 
                                                    subset = 'training',   
                                                    batch_size = batch_size,
                                                    seed = 126,
                                                    shuffle = True,
                                                    class_mode = 'categorical',
                                                    target_size = (image_size,image_size))

valid_generator = valid_datagen.flow_from_directory(directory = '/content/drive/My Drive/인공지능 학습관련/covid데이터',
                                                    subset = 'validation',
                                                    batch_size = valid_size,
                                                    seed = 126,
                                                    shuffle = True,
                                                    class_mode = 'categorical',
                                                    target_size = (image_size,image_size))
print(train_generator.n)
print(valid_generator.n)
# Out:
# Found 12000 images belonging to 3 classes.
# Found 2999 images belonging to 3 classes.
# 12000
# 2999

# %%
# Make model == feature model
feature_model = keras.applications.inception_resnet_v2.InceptionResNetV2(weights="imagenet", include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 3s 0us/step

# %%
# feature_model.save('/content/drive/My Drive/인공지능 학습관련/feature_model229.h5')

# %%
import numpy as np
from tqdm import tqdm

train_features = [] # 빈 리스트 생성 
train_Y = [] # 빈 리스트 생성 

for idx in tqdm(range(train_generator.n)): # 2785 
    if idx % 1000 == 0: #만약 0 포함 100의 배수일때 
        print(idx) #(진행상황 표기)
    x, y = train_generator.next() #next()를 활용하여 train_generator에 담겨진 [[입력픽셀],[라벨링]] 을 x와 y에 담아 준다.  
    train_Y.extend(y) #append()와 비슷한 기능, list에 appending 수행
    #   print(x.shape, y.shape) --> (32, 299, 299, 3), (32, 120)
    # feature_model : 이미 학습이 완료된 특징 추출기 (우리가 불러옴)
    # 학습데이터 x 를 활용해서 feature_model을 통과시켜 특징 추출.
    feature = feature_model.predict(x)
    #   print(feature.shape) --> (32,2048)
    train_features.extend(feature)

#array 전환 
train_features = np.array(train_features)
train_Y = np.array(train_Y)

print(train_features.shape) 
print(train_Y.shape)
# Out:
#   0%|          | 0/12000 [00:00<?, ?it/s]
# 0
#   8%|▊         | 1000/12000 [09:34<1:22:56,  2.21it/s]
# 1000
#  17%|█▋        | 2000/12000 [18:34<1:44:25,  1.60it/s]
# 2000
#  25%|██▌       | 3000/12000 [27:48<1:06:22,  2.26it/s]
# 3000
#  33%|███▎      | 4000/12000 [36:38<1:27:58,  1.52it/s]
# 4000
#  42%|████▏     | 5000/12000 [44:47<54:59,  2.12it/s]
# 5000
#  50%|█████     | 6000/12000 [53:15<54:14,  1.84it/s]
# 6000
#  58%|█████▊    | 7000/12000 [1:01:43<55:41,  1.50it/s]
# 7000
#  67%|██████▋   | 8000/12000 [1:10:06<29:35,  2.25it/s]
# 8000
#  75%|███████▌  | 9000/12000 [1:18:26<27:35,  1.81it/s]
# 9000
#  83%|████████▎ | 10000/12000 [1:26:41<16:06,  2.07it/s]
# 10000
#  92%|█████████▏| 11000/12000 [1:36:30<07:37,  2.19it/s]
# 11000
# 100%|██████████| 12000/12000 [1:46:36<00:00,  1.88it/s]
# (12000, 8, 8, 1536)
# (12000, 3)

# %%
valid_features = [] # 빈 리스트 생성 
valid_Y = [] # 빈 리스트 생성 
from tqdm import tqdm

for idx in tqdm(range(valid_generator.n)): ## valid_generator.n = 696 (검증데이터의 수)
    if idx % 500 == 0: #만약 0 포함 100의 배수일때 
        print(idx) #(진행상황 표기)
    x, y = valid_generator.next() #next()를 활용하여 valid_generator에 담겨진 [[입력픽셀],[라벨링]] 을 x와 y에 담아 준다.   
    valid_Y.extend(y) #append()와 비슷한 기능, list에 appending 수행
  
    # feature_model : 이미 학습이 완료된 특징 추출기 (우리가 불러옴)
    # 학습데이터 x 를 활용해서 feature_model을 통과시켜 특징 추출.
    feature = feature_model.predict(x)
    valid_features.extend(feature)

#array 전환 
valid_features = np.array(valid_features)
valid_Y = np.array(valid_Y)

print(valid_features.shape)
print(valid_Y.shape)
# Out:
#   0%|          | 0/2999 [00:00<?, ?it/s]
# 0
#  17%|█▋        | 500/2999 [04:32<22:24,  1.86it/s]
# 500
#  33%|███▎      | 1000/2999 [09:05<13:14,  2.52it/s]
# 1000
#  50%|█████     | 1500/2999 [13:47<09:53,  2.52it/s]
# 1500
#  67%|██████▋   | 2000/2999 [18:44<07:23,  2.25it/s]
# 2000
#  83%|████████▎ | 2500/2999 [23:09<03:52,  2.14it/s]
# 2500
# 100%|██████████| 2999/2999 [27:10<00:00,  1.84it/s]
# (2999, 8, 8, 1536)
# (2999, 3)

# %%
# Make Classifier Model
def create_model():
    input = Input(shape=feature_model.output.shape[1:])

    x = GlobalAveragePooling2D()(input)

    x = Dense(512, activation='relu')(x)

    x = tf.keras.layers.Dropout(0.6)(x)

    predictions = Dense(3, activation='softmax')(x)

    model = Model(inputs=input, outputs=predictions)
    model.compile(tf.optimizers.RMSprop(0.0001), 
                loss = 'categorical_crossentropy',
                metrics=['accuracy'])
    return model


# 모델 객체를 만듬
model = create_model()

checkpoint_path = '/content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs'

cp = ModelCheckpoint(filepath=checkpoint_path,
                                save_weights_only=True,
                                save_best_only=True,
                                monitor='val_accuracy',
                                verbose=1)
                    
es = EarlyStopping(patience=70, verbose=1)
history = model.fit(train_features, train_Y, 
                    validation_data=(valid_features, valid_Y),
                    epochs = 200,
                    batch_size = 32,
                    callbacks=[es,cp])
model.summary()
# Out:
# Epoch 1/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.4035 - accuracy: 0.8401
# Epoch 00001: val_accuracy improved from -inf to 0.94065, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 8ms/step - loss: 0.4021 - accuracy: 0.8408 - val_loss: 0.1835 - val_accuracy: 0.9406
# Epoch 2/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.2584 - accuracy: 0.9034
# Epoch 00002: val_accuracy improved from 0.94065 to 0.94198, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2582 - accuracy: 0.9035 - val_loss: 0.1568 - val_accuracy: 0.9420
# Epoch 3/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.2240 - accuracy: 0.9169
# Epoch 00003: val_accuracy improved from 0.94198 to 0.95032, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2247 - accuracy: 0.9167 - val_loss: 0.1419 - val_accuracy: 0.9503
# Epoch 4/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.2049 - accuracy: 0.9245
# Epoch 00004: val_accuracy improved from 0.95032 to 0.95165, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2049 - accuracy: 0.9247 - val_loss: 0.1327 - val_accuracy: 0.9517
# Epoch 5/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.1915 - accuracy: 0.9283
# Epoch 00005: val_accuracy improved from 0.95165 to 0.95265, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1913 - accuracy: 0.9284 - val_loss: 0.1285 - val_accuracy: 0.9527
# Epoch 6/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.1825 - accuracy: 0.9331
# Epoch 00006: val_accuracy improved from 0.95265 to 0.95999, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1822 - accuracy: 0.9331 - val_loss: 0.1123 - val_accuracy: 0.9600
# Epoch 7/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.1725 - accuracy: 0.9387
# Epoch 00007: val_accuracy did not improve from 0.95999
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1725 - accuracy: 0.9388 - val_loss: 0.1114 - val_accuracy: 0.9590
# Epoch 8/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.1646 - accuracy: 0.9429
# Epoch 00008: val_accuracy did not improve from 0.95999
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1642 - accuracy: 0.9433 - val_loss: 0.1046 - val_accuracy: 0.9597
# Epoch 9/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.1621 - accuracy: 0.9418
# Epoch 00009: val_accuracy did not improve from 0.95999
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1624 - accuracy: 0.9417 - val_loss: 0.1217 - val_accuracy: 0.9540
# Epoch 10/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.1542 - accuracy: 0.9441
# Epoch 00010: val_accuracy did not improve from 0.95999
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1539 - accuracy: 0.9442 - val_loss: 0.1035 - val_accuracy: 0.9590
# Epoch 11/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.1502 - accuracy: 0.9464
# Epoch 00011: val_accuracy did not improve from 0.95999
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1500 - accuracy: 0.9464 - val_loss: 0.0993 - val_accuracy: 0.9593
# Epoch 12/200
# 366/375 [============================>.] - ETA: 0s - loss: 0.1469 - accuracy: 0.9471
# Epoch 00012: val_accuracy improved from 0.95999 to 0.96199, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1464 - accuracy: 0.9474 - val_loss: 0.1007 - val_accuracy: 0.9620
# Epoch 13/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.1449 - accuracy: 0.9480
# Epoch 00013: val_accuracy did not improve from 0.96199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1447 - accuracy: 0.9482 - val_loss: 0.1297 - val_accuracy: 0.9486
# Epoch 14/200
# 375/375 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9526
# Epoch 00014: val_accuracy did not improve from 0.96199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1375 - accuracy: 0.9526 - val_loss: 0.1032 - val_accuracy: 0.9597
# Epoch 15/200
# 366/375 [============================>.] - ETA: 0s - loss: 0.1376 - accuracy: 0.9516
# Epoch 00015: val_accuracy did not improve from 0.96199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1367 - accuracy: 0.9519 - val_loss: 0.0987 - val_accuracy: 0.9607
# Epoch 16/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.1288 - accuracy: 0.9546
# Epoch 00016: val_accuracy improved from 0.96199 to 0.96432, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1281 - accuracy: 0.9548 - val_loss: 0.0882 - val_accuracy: 0.9643
# Epoch 17/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.1299 - accuracy: 0.9555
# Epoch 00017: val_accuracy did not improve from 0.96432
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1300 - accuracy: 0.9556 - val_loss: 0.0920 - val_accuracy: 0.9617
# Epoch 18/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.1265 - accuracy: 0.9558
# Epoch 00018: val_accuracy did not improve from 0.96432
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1265 - accuracy: 0.9557 - val_loss: 0.0904 - val_accuracy: 0.9613
# Epoch 19/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.1275 - accuracy: 0.9550
# Epoch 00019: val_accuracy improved from 0.96432 to 0.96499, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1273 - accuracy: 0.9552 - val_loss: 0.0856 - val_accuracy: 0.9650
# Epoch 20/200
# 375/375 [==============================] - ETA: 0s - loss: 0.1196 - accuracy: 0.9569
# Epoch 00020: val_accuracy did not improve from 0.96499
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1196 - accuracy: 0.9569 - val_loss: 0.1068 - val_accuracy: 0.9610
# Epoch 21/200
# 366/375 [============================>.] - ETA: 0s - loss: 0.1178 - accuracy: 0.9588
# Epoch 00021: val_accuracy did not improve from 0.96499
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1204 - accuracy: 0.9580 - val_loss: 0.0962 - val_accuracy: 0.9637
# Epoch 22/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.1197 - accuracy: 0.9593
# Epoch 00022: val_accuracy did not improve from 0.96499
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1196 - accuracy: 0.9594 - val_loss: 0.1116 - val_accuracy: 0.9583
# Epoch 23/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.1181 - accuracy: 0.9591
# Epoch 00023: val_accuracy did not improve from 0.96499
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1182 - accuracy: 0.9591 - val_loss: 0.0874 - val_accuracy: 0.9637
# Epoch 24/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.1147 - accuracy: 0.9594
# Epoch 00024: val_accuracy improved from 0.96499 to 0.97066, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 8ms/step - loss: 0.1153 - accuracy: 0.9592 - val_loss: 0.0806 - val_accuracy: 0.9707
# Epoch 25/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.1107 - accuracy: 0.9609
# Epoch 00025: val_accuracy did not improve from 0.97066
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1104 - accuracy: 0.9609 - val_loss: 0.1020 - val_accuracy: 0.9600
# Epoch 26/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.1090 - accuracy: 0.9609
# Epoch 00026: val_accuracy did not improve from 0.97066
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1086 - accuracy: 0.9612 - val_loss: 0.0920 - val_accuracy: 0.9663
# Epoch 27/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.1078 - accuracy: 0.9627
# Epoch 00027: val_accuracy did not improve from 0.97066
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1079 - accuracy: 0.9627 - val_loss: 0.0775 - val_accuracy: 0.9687
# Epoch 28/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.1066 - accuracy: 0.9631
# Epoch 00028: val_accuracy did not improve from 0.97066
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1069 - accuracy: 0.9631 - val_loss: 0.0937 - val_accuracy: 0.9633
# Epoch 29/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.1033 - accuracy: 0.9641
# Epoch 00029: val_accuracy did not improve from 0.97066
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1035 - accuracy: 0.9639 - val_loss: 0.0825 - val_accuracy: 0.9680
# Epoch 30/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.1039 - accuracy: 0.9634
# Epoch 00030: val_accuracy improved from 0.97066 to 0.97099, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1045 - accuracy: 0.9633 - val_loss: 0.0721 - val_accuracy: 0.9710
# Epoch 31/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.1036 - accuracy: 0.9637
# Epoch 00031: val_accuracy did not improve from 0.97099
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1035 - accuracy: 0.9638 - val_loss: 0.0810 - val_accuracy: 0.9690
# Epoch 32/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.1035 - accuracy: 0.9649
# Epoch 00032: val_accuracy did not improve from 0.97099
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1036 - accuracy: 0.9649 - val_loss: 0.0803 - val_accuracy: 0.9690
# Epoch 33/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0992 - accuracy: 0.9651
# Epoch 00033: val_accuracy did not improve from 0.97099
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0991 - accuracy: 0.9651 - val_loss: 0.0902 - val_accuracy: 0.9673
# Epoch 34/200
# 375/375 [==============================] - ETA: 0s - loss: 0.1003 - accuracy: 0.9671
# Epoch 00034: val_accuracy improved from 0.97099 to 0.97232, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1003 - accuracy: 0.9671 - val_loss: 0.0764 - val_accuracy: 0.9723
# Epoch 35/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0969 - accuracy: 0.9682
# Epoch 00035: val_accuracy did not improve from 0.97232
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0969 - accuracy: 0.9682 - val_loss: 0.0810 - val_accuracy: 0.9690
# Epoch 36/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.0994 - accuracy: 0.9654
# Epoch 00036: val_accuracy did not improve from 0.97232
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1003 - accuracy: 0.9648 - val_loss: 0.0799 - val_accuracy: 0.9707
# Epoch 37/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0945 - accuracy: 0.9681
# Epoch 00037: val_accuracy did not improve from 0.97232
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0944 - accuracy: 0.9678 - val_loss: 0.0751 - val_accuracy: 0.9717
# Epoch 38/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0955 - accuracy: 0.9680
# Epoch 00038: val_accuracy did not improve from 0.97232
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0952 - accuracy: 0.9681 - val_loss: 0.0755 - val_accuracy: 0.9703
# Epoch 39/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9688
# Epoch 00039: val_accuracy did not improve from 0.97232
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0937 - accuracy: 0.9688 - val_loss: 0.0752 - val_accuracy: 0.9723
# Epoch 40/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0903 - accuracy: 0.9691
# Epoch 00040: val_accuracy did not improve from 0.97232
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0899 - accuracy: 0.9693 - val_loss: 0.0918 - val_accuracy: 0.9660
# Epoch 41/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0877 - accuracy: 0.9723
# Epoch 00041: val_accuracy did not improve from 0.97232
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0879 - accuracy: 0.9720 - val_loss: 0.0760 - val_accuracy: 0.9703
# Epoch 42/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.0888 - accuracy: 0.9685
# Epoch 00042: val_accuracy did not improve from 0.97232
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0885 - accuracy: 0.9687 - val_loss: 0.0851 - val_accuracy: 0.9697
# Epoch 43/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.0888 - accuracy: 0.9702
# Epoch 00043: val_accuracy did not improve from 0.97232
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0891 - accuracy: 0.9702 - val_loss: 0.0915 - val_accuracy: 0.9660
# Epoch 44/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0868 - accuracy: 0.9710
# Epoch 00044: val_accuracy did not improve from 0.97232
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0865 - accuracy: 0.9711 - val_loss: 0.0813 - val_accuracy: 0.9710
# Epoch 45/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.0845 - accuracy: 0.9709
# Epoch 00045: val_accuracy improved from 0.97232 to 0.97266, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0850 - accuracy: 0.9706 - val_loss: 0.0688 - val_accuracy: 0.9727
# Epoch 46/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0874 - accuracy: 0.9710
# Epoch 00046: val_accuracy improved from 0.97266 to 0.97432, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0870 - accuracy: 0.9711 - val_loss: 0.0780 - val_accuracy: 0.9743
# Epoch 47/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.0837 - accuracy: 0.9717
# Epoch 00047: val_accuracy did not improve from 0.97432
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0833 - accuracy: 0.9718 - val_loss: 0.0761 - val_accuracy: 0.9723
# Epoch 48/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0841 - accuracy: 0.9715
# Epoch 00048: val_accuracy did not improve from 0.97432
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0839 - accuracy: 0.9716 - val_loss: 0.0710 - val_accuracy: 0.9727
# Epoch 49/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9720
# Epoch 00049: val_accuracy did not improve from 0.97432
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0831 - accuracy: 0.9720 - val_loss: 0.0726 - val_accuracy: 0.9717
# Epoch 50/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.0820 - accuracy: 0.9727
# Epoch 00050: val_accuracy did not improve from 0.97432
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0826 - accuracy: 0.9726 - val_loss: 0.0763 - val_accuracy: 0.9723
# Epoch 51/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0797 - accuracy: 0.9735
# Epoch 00051: val_accuracy did not improve from 0.97432
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0795 - accuracy: 0.9735 - val_loss: 0.0896 - val_accuracy: 0.9680
# Epoch 52/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0806 - accuracy: 0.9734
# Epoch 00052: val_accuracy improved from 0.97432 to 0.97466, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0803 - accuracy: 0.9735 - val_loss: 0.0749 - val_accuracy: 0.9747
# Epoch 53/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0783 - accuracy: 0.9743
# Epoch 00053: val_accuracy did not improve from 0.97466
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0783 - accuracy: 0.9743 - val_loss: 0.0748 - val_accuracy: 0.9730
# Epoch 54/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0791 - accuracy: 0.9738
# Epoch 00054: val_accuracy did not improve from 0.97466
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0791 - accuracy: 0.9738 - val_loss: 0.0836 - val_accuracy: 0.9700
# Epoch 55/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0772 - accuracy: 0.9737
# Epoch 00055: val_accuracy improved from 0.97466 to 0.97499, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0776 - accuracy: 0.9736 - val_loss: 0.0665 - val_accuracy: 0.9750
# Epoch 56/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.0764 - accuracy: 0.9745
# Epoch 00056: val_accuracy did not improve from 0.97499
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0765 - accuracy: 0.9743 - val_loss: 0.0851 - val_accuracy: 0.9683
# Epoch 57/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.0734 - accuracy: 0.9758
# Epoch 00057: val_accuracy improved from 0.97499 to 0.97599, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0728 - accuracy: 0.9760 - val_loss: 0.0664 - val_accuracy: 0.9760
# Epoch 58/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0733 - accuracy: 0.9766
# Epoch 00058: val_accuracy did not improve from 0.97599
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0730 - accuracy: 0.9768 - val_loss: 0.1142 - val_accuracy: 0.9617
# Epoch 59/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.0761 - accuracy: 0.9751
# Epoch 00059: val_accuracy did not improve from 0.97599
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0767 - accuracy: 0.9749 - val_loss: 0.0686 - val_accuracy: 0.9753
# Epoch 60/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.0718 - accuracy: 0.9776
# Epoch 00060: val_accuracy did not improve from 0.97599
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0720 - accuracy: 0.9777 - val_loss: 0.0778 - val_accuracy: 0.9727
# Epoch 61/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0726 - accuracy: 0.9759
# Epoch 00061: val_accuracy did not improve from 0.97599
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0735 - accuracy: 0.9759 - val_loss: 0.0730 - val_accuracy: 0.9727
# Epoch 62/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.0718 - accuracy: 0.9760
# Epoch 00062: val_accuracy did not improve from 0.97599
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0720 - accuracy: 0.9759 - val_loss: 0.0825 - val_accuracy: 0.9717
# Epoch 63/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0706 - accuracy: 0.9777
# Epoch 00063: val_accuracy did not improve from 0.97599
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0711 - accuracy: 0.9776 - val_loss: 0.0702 - val_accuracy: 0.9743
# Epoch 64/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0698 - accuracy: 0.9761
# Epoch 00064: val_accuracy did not improve from 0.97599
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0697 - accuracy: 0.9761 - val_loss: 0.0723 - val_accuracy: 0.9730
# Epoch 65/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.0702 - accuracy: 0.9771
# Epoch 00065: val_accuracy did not improve from 0.97599
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0703 - accuracy: 0.9770 - val_loss: 0.0711 - val_accuracy: 0.9740
# Epoch 66/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.0693 - accuracy: 0.9766
# Epoch 00066: val_accuracy improved from 0.97599 to 0.97699, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0691 - accuracy: 0.9767 - val_loss: 0.0690 - val_accuracy: 0.9770
# Epoch 67/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0660 - accuracy: 0.9777
# Epoch 00067: val_accuracy did not improve from 0.97699
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0659 - accuracy: 0.9778 - val_loss: 0.0757 - val_accuracy: 0.9730
# Epoch 68/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0693 - accuracy: 0.9786
# Epoch 00068: val_accuracy did not improve from 0.97699
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0692 - accuracy: 0.9785 - val_loss: 0.0630 - val_accuracy: 0.9763
# Epoch 69/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.0676 - accuracy: 0.9775
# Epoch 00069: val_accuracy did not improve from 0.97699
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0678 - accuracy: 0.9773 - val_loss: 0.0693 - val_accuracy: 0.9757
# Epoch 70/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0672 - accuracy: 0.9795
# Epoch 00070: val_accuracy did not improve from 0.97699
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0667 - accuracy: 0.9797 - val_loss: 0.0850 - val_accuracy: 0.9710
# Epoch 71/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.0634 - accuracy: 0.9789
# Epoch 00071: val_accuracy did not improve from 0.97699
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0632 - accuracy: 0.9789 - val_loss: 0.0669 - val_accuracy: 0.9770
# Epoch 72/200
# 366/375 [============================>.] - ETA: 0s - loss: 0.0650 - accuracy: 0.9792
# Epoch 00072: val_accuracy did not improve from 0.97699
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0649 - accuracy: 0.9793 - val_loss: 0.0644 - val_accuracy: 0.9763
# Epoch 73/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.0660 - accuracy: 0.9787
# Epoch 00073: val_accuracy did not improve from 0.97699
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0662 - accuracy: 0.9787 - val_loss: 0.0754 - val_accuracy: 0.9740
# Epoch 74/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0652 - accuracy: 0.9788
# Epoch 00074: val_accuracy improved from 0.97699 to 0.97866, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0646 - accuracy: 0.9790 - val_loss: 0.0676 - val_accuracy: 0.9787
# Epoch 75/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0659 - accuracy: 0.9773
# Epoch 00075: val_accuracy did not improve from 0.97866
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0659 - accuracy: 0.9773 - val_loss: 0.0644 - val_accuracy: 0.9777
# Epoch 76/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0632 - accuracy: 0.9794
# Epoch 00076: val_accuracy did not improve from 0.97866
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0633 - accuracy: 0.9793 - val_loss: 0.0710 - val_accuracy: 0.9763
# Epoch 77/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0628 - accuracy: 0.9779
# Epoch 00077: val_accuracy did not improve from 0.97866
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0626 - accuracy: 0.9778 - val_loss: 0.0717 - val_accuracy: 0.9737
# Epoch 78/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.0649 - accuracy: 0.9786
# Epoch 00078: val_accuracy did not improve from 0.97866
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0644 - accuracy: 0.9787 - val_loss: 0.0760 - val_accuracy: 0.9743
# Epoch 79/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0611 - accuracy: 0.9798
# Epoch 00079: val_accuracy did not improve from 0.97866
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0608 - accuracy: 0.9799 - val_loss: 0.0742 - val_accuracy: 0.9760
# Epoch 80/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0630 - accuracy: 0.9809
# Epoch 00080: val_accuracy did not improve from 0.97866
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0630 - accuracy: 0.9809 - val_loss: 0.1054 - val_accuracy: 0.9677
# Epoch 81/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0607 - accuracy: 0.9801
# Epoch 00081: val_accuracy did not improve from 0.97866
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0610 - accuracy: 0.9801 - val_loss: 0.0661 - val_accuracy: 0.9770
# Epoch 82/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9808
# Epoch 00082: val_accuracy did not improve from 0.97866
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0584 - accuracy: 0.9808 - val_loss: 0.0666 - val_accuracy: 0.9767
# Epoch 83/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.0613 - accuracy: 0.9801
# Epoch 00083: val_accuracy did not improve from 0.97866
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0611 - accuracy: 0.9802 - val_loss: 0.0662 - val_accuracy: 0.9777
# Epoch 84/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9822
# Epoch 00084: val_accuracy did not improve from 0.97866
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0589 - accuracy: 0.9822 - val_loss: 0.1262 - val_accuracy: 0.9617
# Epoch 85/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0600 - accuracy: 0.9789
# Epoch 00085: val_accuracy did not improve from 0.97866
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0599 - accuracy: 0.9789 - val_loss: 0.0718 - val_accuracy: 0.9747
# Epoch 86/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0585 - accuracy: 0.9803
# Epoch 00086: val_accuracy improved from 0.97866 to 0.97899, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0584 - accuracy: 0.9803 - val_loss: 0.0616 - val_accuracy: 0.9790
# Epoch 87/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.0572 - accuracy: 0.9810
# Epoch 00087: val_accuracy did not improve from 0.97899
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0568 - accuracy: 0.9812 - val_loss: 0.0730 - val_accuracy: 0.9743
# Epoch 88/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.0561 - accuracy: 0.9825
# Epoch 00088: val_accuracy did not improve from 0.97899
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0560 - accuracy: 0.9826 - val_loss: 0.0918 - val_accuracy: 0.9747
# Epoch 89/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0575 - accuracy: 0.9818
# Epoch 00089: val_accuracy improved from 0.97899 to 0.98033, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0573 - accuracy: 0.9818 - val_loss: 0.0583 - val_accuracy: 0.9803
# Epoch 90/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0543 - accuracy: 0.9828
# Epoch 00090: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0543 - accuracy: 0.9828 - val_loss: 0.0598 - val_accuracy: 0.9783
# Epoch 91/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9809
# Epoch 00091: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0583 - accuracy: 0.9809 - val_loss: 0.0615 - val_accuracy: 0.9797
# Epoch 92/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0546 - accuracy: 0.9819
# Epoch 00092: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0546 - accuracy: 0.9818 - val_loss: 0.0686 - val_accuracy: 0.9780
# Epoch 93/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.0591 - accuracy: 0.9810
# Epoch 00093: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0588 - accuracy: 0.9811 - val_loss: 0.0616 - val_accuracy: 0.9780
# Epoch 94/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0551 - accuracy: 0.9835
# Epoch 00094: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0554 - accuracy: 0.9835 - val_loss: 0.0706 - val_accuracy: 0.9757
# Epoch 95/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.0539 - accuracy: 0.9816
# Epoch 00095: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0541 - accuracy: 0.9815 - val_loss: 0.0755 - val_accuracy: 0.9743
# Epoch 96/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0544 - accuracy: 0.9825
# Epoch 00096: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0548 - accuracy: 0.9824 - val_loss: 0.0650 - val_accuracy: 0.9763
# Epoch 97/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.0555 - accuracy: 0.9823
# Epoch 00097: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0550 - accuracy: 0.9825 - val_loss: 0.0580 - val_accuracy: 0.9793
# Epoch 98/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0500 - accuracy: 0.9838
# Epoch 00098: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0503 - accuracy: 0.9837 - val_loss: 0.0718 - val_accuracy: 0.9767
# Epoch 99/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0519 - accuracy: 0.9832
# Epoch 00099: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0512 - accuracy: 0.9835 - val_loss: 0.0693 - val_accuracy: 0.9760
# Epoch 100/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0515 - accuracy: 0.9835
# Epoch 00100: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0514 - accuracy: 0.9835 - val_loss: 0.0763 - val_accuracy: 0.9783
# Epoch 101/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.0546 - accuracy: 0.9841
# Epoch 00101: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0545 - accuracy: 0.9839 - val_loss: 0.0720 - val_accuracy: 0.9763
# Epoch 102/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0531 - accuracy: 0.9833
# Epoch 00102: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0531 - accuracy: 0.9833 - val_loss: 0.1050 - val_accuracy: 0.9673
# Epoch 103/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9834
# Epoch 00103: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0503 - accuracy: 0.9834 - val_loss: 0.0866 - val_accuracy: 0.9760
# Epoch 104/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0495 - accuracy: 0.9836
# Epoch 00104: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0492 - accuracy: 0.9836 - val_loss: 0.0692 - val_accuracy: 0.9770
# Epoch 105/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9836
# Epoch 00105: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0499 - accuracy: 0.9837 - val_loss: 0.0859 - val_accuracy: 0.9737
# Epoch 106/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9835
# Epoch 00106: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0507 - accuracy: 0.9835 - val_loss: 0.0754 - val_accuracy: 0.9770
# Epoch 107/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9844
# Epoch 00107: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0508 - accuracy: 0.9844 - val_loss: 0.0952 - val_accuracy: 0.9697
# Epoch 108/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.0500 - accuracy: 0.9829
# Epoch 00108: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0500 - accuracy: 0.9829 - val_loss: 0.0773 - val_accuracy: 0.9763
# Epoch 109/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0487 - accuracy: 0.9846
# Epoch 00109: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0489 - accuracy: 0.9843 - val_loss: 0.0681 - val_accuracy: 0.9773
# Epoch 110/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.0486 - accuracy: 0.9855
# Epoch 00110: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0485 - accuracy: 0.9855 - val_loss: 0.0700 - val_accuracy: 0.9767
# Epoch 111/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0463 - accuracy: 0.9850
# Epoch 00111: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0462 - accuracy: 0.9851 - val_loss: 0.0773 - val_accuracy: 0.9757
# Epoch 112/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9843
# Epoch 00112: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0507 - accuracy: 0.9841 - val_loss: 0.0647 - val_accuracy: 0.9780
# Epoch 113/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0482 - accuracy: 0.9826
# Epoch 00113: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0488 - accuracy: 0.9826 - val_loss: 0.0648 - val_accuracy: 0.9773
# Epoch 114/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0495 - accuracy: 0.9848
# Epoch 00114: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0495 - accuracy: 0.9848 - val_loss: 0.0627 - val_accuracy: 0.9793
# Epoch 115/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.0477 - accuracy: 0.9842
# Epoch 00115: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0478 - accuracy: 0.9840 - val_loss: 0.0722 - val_accuracy: 0.9773
# Epoch 116/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9857
# Epoch 00116: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0459 - accuracy: 0.9857 - val_loss: 0.0820 - val_accuracy: 0.9767
# Epoch 117/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.0459 - accuracy: 0.9858
# Epoch 00117: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0467 - accuracy: 0.9858 - val_loss: 0.0743 - val_accuracy: 0.9757
# Epoch 118/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0466 - accuracy: 0.9852
# Epoch 00118: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0460 - accuracy: 0.9853 - val_loss: 0.0707 - val_accuracy: 0.9767
# Epoch 119/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9864
# Epoch 00119: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0427 - accuracy: 0.9862 - val_loss: 0.0654 - val_accuracy: 0.9793
# Epoch 120/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0467 - accuracy: 0.9837
# Epoch 00120: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0467 - accuracy: 0.9837 - val_loss: 0.0641 - val_accuracy: 0.9780
# Epoch 121/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0467 - accuracy: 0.9855
# Epoch 00121: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0467 - accuracy: 0.9856 - val_loss: 0.0678 - val_accuracy: 0.9777
# Epoch 122/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.0440 - accuracy: 0.9863
# Epoch 00122: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0454 - accuracy: 0.9861 - val_loss: 0.0836 - val_accuracy: 0.9760
# Epoch 123/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0430 - accuracy: 0.9868
# Epoch 00123: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0428 - accuracy: 0.9869 - val_loss: 0.0762 - val_accuracy: 0.9760
# Epoch 124/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0485 - accuracy: 0.9853
# Epoch 00124: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0487 - accuracy: 0.9852 - val_loss: 0.0641 - val_accuracy: 0.9783
# Epoch 125/200
# 366/375 [============================>.] - ETA: 0s - loss: 0.0455 - accuracy: 0.9861
# Epoch 00125: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0447 - accuracy: 0.9864 - val_loss: 0.0682 - val_accuracy: 0.9787
# Epoch 126/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9845
# Epoch 00126: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0505 - accuracy: 0.9847 - val_loss: 0.0668 - val_accuracy: 0.9777
# Epoch 127/200
# 374/375 [============================>.] - ETA: 0s - loss: 0.0444 - accuracy: 0.9860
# Epoch 00127: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0444 - accuracy: 0.9859 - val_loss: 0.0849 - val_accuracy: 0.9737
# Epoch 128/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.0446 - accuracy: 0.9858
# Epoch 00128: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0454 - accuracy: 0.9857 - val_loss: 0.0826 - val_accuracy: 0.9760
# Epoch 129/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.0392 - accuracy: 0.9872
# Epoch 00129: val_accuracy did not improve from 0.98033
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0394 - accuracy: 0.9871 - val_loss: 0.0738 - val_accuracy: 0.9787
# Epoch 130/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9871
# Epoch 00130: val_accuracy improved from 0.98033 to 0.98199, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0440 - accuracy: 0.9869 - val_loss: 0.0606 - val_accuracy: 0.9820
# Epoch 131/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.0430 - accuracy: 0.9864
# Epoch 00131: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0427 - accuracy: 0.9863 - val_loss: 0.0595 - val_accuracy: 0.9790
# Epoch 132/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.0419 - accuracy: 0.9866
# Epoch 00132: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0427 - accuracy: 0.9864 - val_loss: 0.0710 - val_accuracy: 0.9777
# Epoch 133/200
# 367/375 [============================>.] - ETA: 0s - loss: 0.0386 - accuracy: 0.9868
# Epoch 00133: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0389 - accuracy: 0.9868 - val_loss: 0.0788 - val_accuracy: 0.9767
# Epoch 134/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0407 - accuracy: 0.9869
# Epoch 00134: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0406 - accuracy: 0.9869 - val_loss: 0.0835 - val_accuracy: 0.9760
# Epoch 135/200
# 366/375 [============================>.] - ETA: 0s - loss: 0.0423 - accuracy: 0.9869
# Epoch 00135: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0422 - accuracy: 0.9868 - val_loss: 0.0686 - val_accuracy: 0.9783
# Epoch 136/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.0421 - accuracy: 0.9876
# Epoch 00136: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0421 - accuracy: 0.9874 - val_loss: 0.0799 - val_accuracy: 0.9777
# Epoch 137/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.0413 - accuracy: 0.9863
# Epoch 00137: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0420 - accuracy: 0.9861 - val_loss: 0.0620 - val_accuracy: 0.9807
# Epoch 138/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0405 - accuracy: 0.9876
# Epoch 00138: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0401 - accuracy: 0.9877 - val_loss: 0.0727 - val_accuracy: 0.9800
# Epoch 139/200
# 366/375 [============================>.] - ETA: 0s - loss: 0.0409 - accuracy: 0.9868
# Epoch 00139: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0410 - accuracy: 0.9868 - val_loss: 0.0723 - val_accuracy: 0.9773
# Epoch 140/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9884
# Epoch 00140: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0393 - accuracy: 0.9884 - val_loss: 0.0874 - val_accuracy: 0.9763
# Epoch 141/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.0390 - accuracy: 0.9873
# Epoch 00141: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0389 - accuracy: 0.9872 - val_loss: 0.0807 - val_accuracy: 0.9793
# Epoch 142/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9864
# Epoch 00142: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0419 - accuracy: 0.9859 - val_loss: 0.0736 - val_accuracy: 0.9777
# Epoch 143/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0405 - accuracy: 0.9871
# Epoch 00143: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0408 - accuracy: 0.9870 - val_loss: 0.0591 - val_accuracy: 0.9797
# Epoch 144/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0383 - accuracy: 0.9883
# Epoch 00144: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0382 - accuracy: 0.9883 - val_loss: 0.0792 - val_accuracy: 0.9770
# Epoch 145/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0411 - accuracy: 0.9869
# Epoch 00145: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0411 - accuracy: 0.9868 - val_loss: 0.0614 - val_accuracy: 0.9803
# Epoch 146/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0388 - accuracy: 0.9878
# Epoch 00146: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0387 - accuracy: 0.9877 - val_loss: 0.0843 - val_accuracy: 0.9740
# Epoch 147/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9878
# Epoch 00147: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0380 - accuracy: 0.9878 - val_loss: 0.0767 - val_accuracy: 0.9770
# Epoch 148/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0387 - accuracy: 0.9883
# Epoch 00148: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0386 - accuracy: 0.9883 - val_loss: 0.0675 - val_accuracy: 0.9803
# Epoch 149/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.0370 - accuracy: 0.9879
# Epoch 00149: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0370 - accuracy: 0.9878 - val_loss: 0.0768 - val_accuracy: 0.9757
# Epoch 150/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9864
# Epoch 00150: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0408 - accuracy: 0.9866 - val_loss: 0.0690 - val_accuracy: 0.9803
# Epoch 151/200
# 366/375 [============================>.] - ETA: 0s - loss: 0.0390 - accuracy: 0.9879
# Epoch 00151: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0386 - accuracy: 0.9879 - val_loss: 0.0702 - val_accuracy: 0.9800
# Epoch 152/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.0371 - accuracy: 0.9874
# Epoch 00152: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0369 - accuracy: 0.9874 - val_loss: 0.0811 - val_accuracy: 0.9800
# Epoch 153/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0409 - accuracy: 0.9877
# Epoch 00153: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0405 - accuracy: 0.9878 - val_loss: 0.0705 - val_accuracy: 0.9800
# Epoch 154/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0367 - accuracy: 0.9880
# Epoch 00154: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0366 - accuracy: 0.9881 - val_loss: 0.0697 - val_accuracy: 0.9773
# Epoch 155/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0332 - accuracy: 0.9880
# Epoch 00155: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0332 - accuracy: 0.9880 - val_loss: 0.0798 - val_accuracy: 0.9763
# Epoch 156/200
# 371/375 [============================>.] - ETA: 0s - loss: 0.0359 - accuracy: 0.9893
# Epoch 00156: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0357 - accuracy: 0.9893 - val_loss: 0.0613 - val_accuracy: 0.9813
# Epoch 157/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.9890
# Epoch 00157: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0378 - accuracy: 0.9890 - val_loss: 0.0603 - val_accuracy: 0.9803
# Epoch 158/200
# 369/375 [============================>.] - ETA: 0s - loss: 0.0372 - accuracy: 0.9884
# Epoch 00158: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0377 - accuracy: 0.9884 - val_loss: 0.0678 - val_accuracy: 0.9787
# Epoch 159/200
# 366/375 [============================>.] - ETA: 0s - loss: 0.0356 - accuracy: 0.9887
# Epoch 00159: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0359 - accuracy: 0.9887 - val_loss: 0.0950 - val_accuracy: 0.9733
# Epoch 160/200
# 368/375 [============================>.] - ETA: 0s - loss: 0.0384 - accuracy: 0.9879
# Epoch 00160: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0380 - accuracy: 0.9879 - val_loss: 0.0885 - val_accuracy: 0.9747
# Epoch 161/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0382 - accuracy: 0.9878
# Epoch 00161: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0391 - accuracy: 0.9877 - val_loss: 0.0706 - val_accuracy: 0.9777
# Epoch 162/200
# 373/375 [============================>.] - ETA: 0s - loss: 0.0363 - accuracy: 0.9893
# Epoch 00162: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0362 - accuracy: 0.9893 - val_loss: 0.0758 - val_accuracy: 0.9790
# Epoch 163/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0340 - accuracy: 0.9891
# Epoch 00163: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0340 - accuracy: 0.9891 - val_loss: 0.0765 - val_accuracy: 0.9773
# Epoch 164/200
# 375/375 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9873
# Epoch 00164: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0359 - accuracy: 0.9873 - val_loss: 0.0616 - val_accuracy: 0.9813
# Epoch 165/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.0360 - accuracy: 0.9880
# Epoch 00165: val_accuracy did not improve from 0.98199
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0358 - accuracy: 0.9881 - val_loss: 0.0622 - val_accuracy: 0.9797
# Epoch 166/200
# 370/375 [============================>.] - ETA: 0s - loss: 0.0348 - accuracy: 0.9886
# Epoch 00166: val_accuracy improved from 0.98199 to 0.98233, saving model to /content/drive/My Drive/인공지능 학습관련/covid19_detection_model_jpgs
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0349 - accuracy: 0.9886 - val_loss: 0.0588 - val_accuracy: 0.9823
# Epoch 167/200
# 372/375 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9894
# Epoch 00167: val_accuracy did not improve from 0.98233
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0318 - accuracy: 0.9895 - val_loss: 0.0627 - val_accuracy: 0.9813
# Epoch 00167: early stopping
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, None, None, 1536) 0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               786944
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 788,483
# Trainable params: 788,483
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save('/content/drive/My Drive/인공지능 학습관련/covid_model_size299_jpgfiles.h5')

# %%
# 모델 acc/loss 그래프

## summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()
## summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
model2 = create_model()
# 가중치 로드

model2.load_weights(checkpoint_path)

# 모델 평가
# print(model2.evaluate(valid_features, valid_Y))
model2.summary()
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.momentum
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.rho
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, None, None, 1536) 0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1536)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               786944
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 788,483
# Trainable params: 788,483
# Non-trainable params: 0
# _________________________________________________________________

# %%
# from keras.models import model_from_json
# # load json and create model
# json_file = open('/content/drive/My Drive/인공지능 학습관련/covid19_detection_model/model.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)
# # load weights into new model
# loaded_model.load_weights("/content/drive/My Drive/인공지능 학습관련/covid19_detection_model/model.h5")
# print("Loaded model from disk")
# loaded_model.compile(tf.optimizers.RMSprop(0.0001), 
#                 loss = 'categorical_crossentropy',
#                 metrics=['accuracy'])
# Out:
# Loaded model from disk

# %%
model2.save('/content/drive/My Drive/인공지능 학습관련/covid_model_size299_best_jpgs.h5')

# %%
# model2 = load_model('/content/drive/My Drive/인공지능 학습관련/covid_model_size299_4_best.h5')
# model2.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a06653cfa300> in <module>()
# ----> 1 model2 = load_model('/content/drive/My Drive/인공지능 학습관련/covid_model_size299_4_best.h5')
#       2 model2.summary()
#
# NameError: name 'load_model' is not defined

# %%
# feature_model.save('/content/drive/My Drive/인공지능 학습관련/feature_model229_4')
# feature_model2 = load_model('/content/drive/My Drive/인공지능 학습관련/feature_model229_4')
# feature_model2.summary()
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/인공지능 학습관련/feature_model229_4/assets
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 3 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 3 96          conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 3 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 3 9216        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 3 96          conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 3 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 6 18432       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 6 192         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 6 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 6 0           activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 8 5120        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 8 240         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 8 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 1 138240      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 1 576         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 1 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 1 0           activation_35[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 6 12288       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 6 192         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 6 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 4 9216        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 9 55296       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 4 144         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 9 288         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 4 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 9 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, None, None, 1 0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 9 18432       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 6 76800       activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 9 82944       activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 6 12288       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 9 288         conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 6 192         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 9 288         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 6 192         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 9 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 6 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, None, None, 9 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, None, None, 6 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, None, None, 3 0           activation_36[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_41[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 3 96          conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, None, None, 3 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 4 13824       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 3 96          conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 4 144         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, None, None, 3 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, None, None, 4 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 3 9216        activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 6 27648       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 3 96          conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 3 96          conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 6 192         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, None, None, 3 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, None, None, 3 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, None, None, 6 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, None, None, 1 0           activation_43[0][0]
#                                                                  activation_45[0][0]
#                                                                  activation_48[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, None, None, 3 41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, None, None, 3 0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, None, None, 3 0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, None, None, 3 96          conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 3 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 4 13824       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 3 96          conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, None, None, 4 144         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 3 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 4 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 3 9216        activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 6 27648       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, None, None, 3 96          conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 3 96          conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, None, None, 6 192         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, None, None, 3 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 3 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 6 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, None, None, 1 0           activation_49[0][0]
#                                                                  activation_51[0][0]
#                                                                  activation_54[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, None, None, 3 41280       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, None, None, 3 0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, None, None, 3 0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, None, None, 3 96          conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 3 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 4 13824       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 3 96          conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, None, None, 4 144         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 3 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 4 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 3 9216        activation_56[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 6 27648       activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, None, None, 3 96          conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, None, None, 3 96          conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, None, None, 6 192         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 3 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 3 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 6 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, None, None, 1 0           activation_55[0][0]
#                                                                  activation_57[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, None, None, 3 41280       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, None, None, 3 0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, None, None, 3 0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, None, None, 3 96          conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 3 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, None, None, 4 13824       activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, None, None, 3 96          conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, None, None, 4 144         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 3 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 4 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 3 9216        activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, None, None, 6 27648       activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, None, None, 3 96          conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, None, None, 3 96          conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, None, None, 6 192         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 3 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 3 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 6 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, None, None, 1 0           activation_61[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_66[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, None, None, 3 41280       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, None, None, 3 0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, None, None, 3 0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, None, None, 3 96          conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 3 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, None, None, 4 13824       activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, None, None, 3 96          conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, None, None, 4 144         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 3 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 4 0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, None, None, 3 9216        activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, None, None, 6 27648       activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, None, None, 3 96          conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, None, None, 3 96          conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, None, None, 6 192         conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 3 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 3 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, None, 6 0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, None, None, 1 0           activation_67[0][0]
#                                                                  activation_69[0][0]
#                                                                  activation_72[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, None, None, 3 41280       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, None, None, 3 0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, None, None, 3 0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, None, None, 3 96          conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 3 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, None, None, 4 13824       activation_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, None, None, 3 96          conv2d_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, None, None, 4 144         conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 3 0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 4 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, None, None, 3 9216        activation_74[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, None, None, 6 27648       activation_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, None, None, 3 96          conv2d_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, None, None, 3 96          conv2d_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, None, None, 6 192         conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 3 0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 3 0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 6 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, None, None, 1 0           activation_73[0][0]
#                                                                  activation_75[0][0]
#                                                                  activation_78[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, None, None, 3 41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, None, None, 3 0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, None, None, 3 0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, None, None, 3 96          conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 3 0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, None, None, 4 13824       activation_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, None, None, 3 96          conv2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, None, None, 4 144         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 3 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 4 0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, None, None, 3 9216        activation_80[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, None, None, 6 27648       activation_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, None, None, 3 96          conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, None, None, 3 96          conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, None, None, 6 192         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 3 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 3 0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 6 0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, None, None, 1 0           activation_79[0][0]
#                                                                  activation_81[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, None, None, 3 41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, None, None, 3 0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, None, None, 3 0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, None, None, 3 96          conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 3 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, None, None, 4 13824       activation_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, None, None, 3 96          conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, None, None, 4 144         conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 3 0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 4 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, None, None, 3 9216        activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, None, None, 6 27648       activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, None, None, 3 96          conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, None, None, 3 96          conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, None, None, 6 192         conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 3 0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 3 0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, None, None, 6 0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, None, None, 1 0           activation_85[0][0]
#                                                                  activation_87[0][0]
#                                                                  activation_90[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, None, None, 3 41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, None, None, 3 0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, None, None, 3 0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, None, None, 3 96          conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, None, None, 3 0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, None, None, 4 13824       activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, None, None, 3 96          conv2d_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, None, None, 4 144         conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, None, None, 3 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, None, None, 4 0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, None, None, 1 576         conv2d_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, None, None, 2 768         conv2d_218[0][0]
# __________________________________________________________________________________________________
# activation_214 (Activation)     (None, None, None, 1 0           batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# activation_217 (Activation)     (None, None, None, 2 0           batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# block8_6_mixed (Concatenate)    (None, None, None, 4 0           activation_214[0][0]
#                                                                  activation_217[0][0]
# __________________________________________________________________________________________________
# block8_6_conv (Conv2D)          (None, None, None, 2 933920      block8_6_mixed[0][0]
# __________________________________________________________________________________________________
# block8_6 (Lambda)               (None, None, None, 2 0           block8_5_ac[0][0]
#                                                                  block8_6_conv[0][0]
# __________________________________________________________________________________________________
# block8_6_ac (Activation)        (None, None, None, 2 0           block8_6[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, None, None, 1 399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, None, None, 1 576         conv2d_220[0][0]
# __________________________________________________________________________________________________
# activation_219 (Activation)     (None, None, None, 1 0           batch_normalization_220[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, None, None, 2 129024      activation_219[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, None, None, 2 672         conv2d_221[0][0]
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, None, None, 2 0           batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, None, None, 1 399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, None, None, 2 172032      activation_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, None, None, 1 576         conv2d_219[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, None, None, 2 768         conv2d_222[0][0]
# __________________________________________________________________________________________________
# activation_218 (Activation)     (None, None, None, 1 0           batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# activation_221 (Activation)     (None, None, None, 2 0           batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# block8_7_mixed (Concatenate)    (None, None, None, 4 0           activation_218[0][0]
#                                                                  activation_221[0][0]
# __________________________________________________________________________________________________
# block8_7_conv (Conv2D)          (None, None, None, 2 933920      block8_7_mixed[0][0]
# __________________________________________________________________________________________________
# block8_7 (Lambda)               (None, None, None, 2 0           block8_6_ac[0][0]
#                                                                  block8_7_conv[0][0]
# __________________________________________________________________________________________________
# block8_7_ac (Activation)        (None, None, None, 2 0           block8_7[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, None, None, 1 399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, None, None, 1 576         conv2d_224[0][0]
# __________________________________________________________________________________________________
# activation_223 (Activation)     (None, None, None, 1 0           batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, None, None, 2 129024      activation_223[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, None, None, 2 672         conv2d_225[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, None, None, 2 0           batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, None, None, 1 399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, None, None, 2 172032      activation_224[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, None, None, 1 576         conv2d_223[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, None, None, 2 768         conv2d_226[0][0]
# __________________________________________________________________________________________________
# activation_222 (Activation)     (None, None, None, 1 0           batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, None, None, 2 0           batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, None, None, 4 0           activation_222[0][0]
#                                                                  activation_225[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, None, None, 2 933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, None, None, 2 0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, None, None, 2 0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, None, None, 1 399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, None, None, 1 576         conv2d_228[0][0]
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, None, None, 1 0           batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, None, None, 2 129024      activation_227[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, None, None, 2 672         conv2d_229[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, None, None, 2 0           batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, None, None, 1 399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, None, None, 2 172032      activation_228[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, None, None, 1 576         conv2d_227[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, None, None, 2 768         conv2d_230[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, None, None, 1 0           batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# activation_229 (Activation)     (None, None, None, 2 0           batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, None, None, 4 0           activation_226[0][0]
#                                                                  activation_229[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, None, None, 2 933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, None, None, 2 0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, None, None, 2 0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, None, None, 1 399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, None, None, 1 576         conv2d_232[0][0]
# __________________________________________________________________________________________________
# activation_231 (Activation)     (None, None, None, 1 0           batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, None, None, 2 129024      activation_231[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, None, None, 2 672         conv2d_233[0][0]
# __________________________________________________________________________________________________
# activation_232 (Activation)     (None, None, None, 2 0           batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, None, None, 1 399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, None, None, 2 172032      activation_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, None, None, 1 576         conv2d_231[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, None, None, 2 768         conv2d_234[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, None, None, 1 0           batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# activation_233 (Activation)     (None, None, None, 2 0           batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, None, None, 4 0           activation_230[0][0]
#                                                                  activation_233[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, None, None, 2 933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, None, None, 2 0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, None, None, 1 3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, None, None, 1 4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, None, None, 1 0           conv_7b_bn[0][0]
# ==================================================================================================
# Total params: 54,336,736
# Trainable params: 54,276,192
# Non-trainable params: 60,544
# __________________________________________________________________________________________________

# %%
# last_conv_layer_model == feature_model
# 이미지 전처리
def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array

#  히트맵 생성
def make_gradcam_heatmap(img_path, classifier_model, last_conv_layer_model):
    img_size = (299, 299)
    # input배열을 inception_resnet_v2에 맞게 전처리
    img_array = preprocess_input(get_img_array(img_path, size=img_size))


    with tf.GradientTape() as tape:
        # Compute activations of the last conv layer and make the tape watch it
        last_conv_layer_output = last_conv_layer_model(img_array)
        tape.watch(last_conv_layer_output)
        # Compute class predictions
        preds = classifier_model(last_conv_layer_output)
        top_pred_index = tf.argmax(preds[0])
        top_class_channel = preds[:, top_pred_index]

    # This is the gradient of the top predicted class with regard to
    # the output feature map of the last conv layer
    grads = tape.gradient(top_class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    last_conv_layer_output = last_conv_layer_output.numpy()[0]
    pooled_grads = pooled_grads.numpy()
    for i in range(pooled_grads.shape[-1]):
        last_conv_layer_output[:, :, i] *= pooled_grads[i]

    # The channel-wise mean of the resulting feature map
    # is our heatmap of class activation
    heatmap = np.mean(last_conv_layer_output, axis=-1)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = np.maximum(heatmap, 0) / np.max(heatmap)

    # 보정 -- 이미지의 최 외곽부 모두 0
    a = np.vstack((np.zeros(heatmap[:2].shape),heatmap[2:-1]))
    a = np.vstack((a[:-1],np.zeros(heatmap[-1:].shape)))
    for i in a:
        i[0] = 0
        i[-1] = 0
    heatmap = a

    return heatmap

# 감마보정
# gamma correction 
def gamma_correction(img, c=1, g=2.2): 
    out = img.copy() 
    out /= 255. 
    out = (1/c * out) ** (1/g) 
    out *= 255 
    out = out.astype(np.uint8) 
    return out 

# CAM이미지 + 원본
def show_CAM(img_path, heatmap, prediction):
    # We load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    # We rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # We use jet colormap to colorize heatmap
    jet = cm.get_cmap("Reds")

    # We use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # We create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)
    
    # gamma correction
    jet_heatmap = gamma_correction(jet_heatmap, g=2.2)

    # Superimpose the heatmap on original image
    # NORMAL이면 원본이미지만 반환
    if prediction =='NORMAL':
        superimposed_img = img
    else:
        superimposed_img = jet_heatmap *0.5 + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    return superimposed_img

# %%
# from keras.models import load_model
# model = load_model('/content/drive/My Drive/인공지능 학습관련/covid_model_size299_2_best.h5')
# feature_model = load_model('/content/drive/My Drive/인공지능 학습관련/feature_model299.h5')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-0664e55de845> in <module>()
#       1 from keras.models import load_model
# ----> 2 model = load_model('/content/drive/My Drive/인공지능 학습관련/covid_model_size299_2_best.h5')
#       3 feature_model = load_model('/content/drive/My Drive/인공지능 학습관련/feature_model299.h5')
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     180     if (h5py is not None and (
#     181         isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 182       return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     183
#     184     filepath = path_to_string(filepath)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     179
#     180     # set weights
# --> 181     load_weights_from_hdf5_group(f['model_weights'], model.layers)
#     182
#     183     if compile:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/hdf5_format.py in load_weights_from_hdf5_group(f, layers)
#     675   filtered_layer_names = []
#     676   for name in layer_names:
# --> 677     g = f[name]
#     678     weight_names = load_attributes_from_hdf5_group(g, 'weight_names')
#     679     if weight_names:
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/group.py in __getitem__(self, name)
#     262                 raise ValueError("Invalid HDF5 object reference")
#     263         else:
# --> 264             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     265
#     266         otype = h5i.get_type(oid)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5o.pyx in h5py.h5o.open()
#
# h5py/h5i.pyx in h5py.h5i.wrap_identifier()
#
# /usr/lib/python3.6/importlib/_bootstrap.py in parent(self)
#
# KeyboardInterrupt:

# %%
import random
import cv2

predictY = []
realY = []
iter = 100
model = model2

unique_sorted_Y = ['COVID','NORMAL','PNEUMONIA']
plt.figure(figsize=(16,iter*3))



for i in range(iter): 
    image_path = random.choice(valid_generator.filepaths)
    
    #출력 범위 설정 
    plt.subplot(iter,2,i*2+1)

    #검증데이터 출력 
    plt.imshow(plt.imread(image_path))

    # split('/')를 통해 나눠진 부분 중 3번째 획득
    real_y = image_path.split('/')[-2]
    # real_y → bluetick 출력 
    #타이틀 출력 
    plt.title(real_y)
    plt.axis('off')
    #unique_sorted_Y 에 저장된 값을 바탕으로 real_y의 위치 값 할당 
    idx = unique_sorted_Y.index(real_y)
    # idx → ex) 81, ...  


    # # 이미지 확장자 변경
    # image = Image.open(image_path)
    # image_type = image.filename.split('.')[-1]
    # image_name = image.filename.split('.')[0]
    # # if str.lower(image_type) == 'png':
    # # image_type.save(image_name)
    # print(image_name)
    # print(image_type)
    # print(image_name + '.jpeg')
    # image.save(image_name + '.jpeg')

    # image_path = image_name + '.jpeg'


    #예측값 표기
    plt.subplot(iter,2,i * 2+2)
    img_size = (299, 299)
    # 이미지 불러오기 및 이미지 크기 조정
    img = keras.preprocessing.image.load_img(image_path, target_size=img_size)
    # 이미지를 array로 변경
    img = keras.preprocessing.image.img_to_array(img)
    # 각 픽셀값을 0과 1사이의 값으로 조정
    img = img / 255.0
    # 모델의 인풋 타입에 맞게 차원을 하나 늘림
    img = np.expand_dims(img, axis=0)

    #img를 Inception V3의 특징 추출기 feature_model을 활용하여 특징 벡터를 생성. 
    feature_vector = feature_model.predict(img)

    # 앞서 생성한 model 분류기를 통해 예측 수행
    prediction = model.predict(feature_vector)[0]

    #가장 높은 확률의 예측값을 5개 선출 
    #[::-1] Extended Slices 기법으로 내림차순으로 변경, [:5] 그 중 top 5개
    top_3_predict = prediction.argsort()[::-1][:3]
    #labels에 저장 
    labels = [unique_sorted_Y[index] for index in top_3_predict]
    color = ['gray'] * 3
    #예측 수행한 Top 5 값에 대하여 'blue' 으로 변경
    if idx in top_3_predict:
        color[top_3_predict.tolist().index(idx)] = 'blue'
    color = color[::-1]
    #가로 막대 그리기 
    plt.barh(range(3), prediction[top_3_predict][::-1] * 100, color = color)
    plt.yticks(range(3), labels[::-1])

    # print(labels[0], realY[0])
    predictY.append(labels[0])
    realY.append(real_y)
    print(labels[0],real_y)

# %%
# 글자만.
import random
import cv2

predictY = []
realY = []
iter = 1000


unique_sorted_Y = ['COVID','NORMAL','PNEUMONIA']

for i in range(iter): 
    image_path = random.choice(valid_generator.filepaths)
    # split('/')를 통해 나눠진 부분 중 3번째 획득
    real_y = image_path.split('/')[-2]
    # real_y → bluetick 출력 

    img_size = (299, 299)
    # 이미지 불러오기 및 이미지 크기 조정
    img = keras.preprocessing.image.load_img(image_path, target_size=img_size)
    # 이미지를 array로 변경
    img = keras.preprocessing.image.img_to_array(img)
    # 각 픽셀값을 0과 1사이의 값으로 조정
    img = img / 255.0
    # 모델의 인풋 타입에 맞게 차원을 하나 늘림
    img = np.expand_dims(img, axis=0)

    #img를 Inception V3의 특징 추출기 feature_model을 활용하여 특징 벡터를 생성. 
    feature_vector = feature_model.predict(img)

    # 앞서 생성한 model 분류기를 통해 예측 수행
    prediction = model.predict(feature_vector)[0]

    predict = prediction.argmax()
    #labels에 저장 
    label = unique_sorted_Y[predict] 
    
    # print(labels[0], realY[0])
    predictY.append(label)
    realY.append(real_y)
    print(label,real_y)
# Out:
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# COVID COVID
# COVID COVID
# COVID COVID
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL COVID
# NORMAL NORMAL
# NORMAL COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL COVID
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL COVID
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL COVID
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL COVID
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# COVID COVID
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# COVID NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.momentum
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.rho
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# COVID NORMAL
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL COVID
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL COVID
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# COVID COVID
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# COVID COVID
# COVID COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL COVID
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# COVID COVID
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# COVID COVID
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# NORMAL NORMAL
# NORMAL NORMAL
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA
# PNEUMONIA PNEUMONIA

# %%
import itertools
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(predictY, realY)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
plt.figure()
plot_confusion_matrix(cm, classes=['CODVID19', 'NORMAL', 'PNEUMONIA'], title='Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization
# [[106   3   0]
#  [ 13 413   1]
#  [  0   3 461]]
